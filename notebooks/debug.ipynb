# %%
import pandas as pd

# %%
law_df = pd.read_csv("../data/laws_de.csv")

for citation in law_df['citation'].tolist():
    if 'Ziff' in citation:
        print(citation)

# %%
valid_df = pd.read_csv("../data/valid_rewrite_001.csv")
for gold_citations in valid_df['gold_citations'].tolist():
    citation_l = gold_citations.split(";")
    for c in citation_l:
        print(c)
# Out:
# Art. 221 Abs. 1 StPO
# Art. 140 Abs. 1 StGB
# Art. 396 Abs. 1 StPO
# Art. 222 StPO
# Art. 393 Abs. 1 StPO
# Art. 382 Abs. 1 StPO
# Art. 385 Abs. 1 StPO
# Art. 221 Abs. 2 StPO
# Art. 227 Abs. 1 StPO
# Art. 212 Abs. 3 StPO
# Art. 390 Abs. 2 StPO
# Art. 422 Abs. 1 StPO
# Art. 422 Abs. 2 StPO
# Art. 428 Abs. 1 StPO
# Art. 135 Abs. 4 StPO
# Art. 100 Abs. 1 BGG
# Art. 135 Abs. 3 StPO
# Art. 37 Abs. 1 StBOG
# Art. 39 Abs. 1 StBOG
# BGE 137 IV 122 E. 6.2
# BGE 137 IV 122 E. 6.4
# BGE 137 IV 122 E. 4.2
# BGE 132 I 21 E. 3.2
# 1B_210/2023 E. 4.1
# BGE 132 I 21 E. 3.2.2
# 1B_536/2018 E. 5.1
# BGE 139 IV 270 E. 3.1
# BGE 133 I 168 E. 4.1
# BGE 143 IV 168 E. 5.1
# BGE 133 I 270 E. 3.4.2
# BGE 137 IV 122 E. 4.1
# BGE 132 I 21 E. 3.2.1
# 1B_90/2021 E. 2.1
# 1B_90/2021 E. 2.4
# 7B_496/2025 E. 3.2
# 7B_231/2025 E. 4.1
# 7B_69/2024 E. 3.3.2
# 7B_301/2024 E. 2.4
# 7B_12/2025 E. 2.2
# 1B_357/2022 E. 3.1
# 1B_15/2023 E. 3.1
# 1B_28/2022 E. 4.1
# Art. 8 Abs. 1 ATSG
# Art. 8 Abs. 1 IVG
# Art. 17 Abs. 1 IVG
# Art. 1 Abs. 1 IVG
# Art. 56 Abs. 1 ATSG
# Art. 69 Abs. 1 IVG
# Art. 60 Abs. 1 ATSG
# Art. 61 ATSG
# Art. 29 Abs. 1 IVG
# Art. 4 Abs. 1 IVG
# Art. 6 ATSG
# Art. 8 Abs. 3 IVG
# Art. 18d IVG
# Art. 28 Abs. 1 IVG
# Art. 69 Abs. 1bis IVG
# Art. 82 BGG
# Art. 113 BGG
# Art. 100 Abs. 1 BGG
# BGE 148 V 21 E. 5.3
# BGE 144 V 427 E. 3.2
# BGE 139 V 176 E. 5.3
# BGE 135 V 39 E. 6.1
# BGE 132 V 93 E. 4
# 8C_160/2016 E. 4.1
# BGE 134 V 231 E. 5.1
# 8C_510/2020 E. 2.4
# BGE 139 V 399 E. 5.3
# BGE 139 V 399 E. 5.4
# BGE 139 V 399 E. 5.5
# BGE 127 V 205 E. 4b
# Art. 16 ATSG
# Art. 21 Abs. 4 ATSG
# BGE 124 V 108 E. 2b
# 9C_623/2020 E. 4.2
# 8C_421/2023 E. 2.2
# BGE 140 V 193 E. 3.2
# Art. 29 Abs. 2 BV
# Art. 221 Abs. 1 StPO
# Art. 393 Abs. 1 StPO
# Art. 222 StPO
# Art. 384 StPO
# Art. 396 Abs. 1 StPO
# Art. 382 Abs. 1 StPO
# Art. 385 Abs. 1 StPO
# Art. 3 Abs. 2 StPO
# Art. 390 Abs. 2 StPO
# Art. 422 Abs. 1 StPO
# Art. 422 Abs. 2 StPO
# Art. 428 Abs. 1 StPO
# Art. 135 Abs. 4 StPO
# Art. 214 Abs. 4 StPO
# Art. 100 Abs. 1 BGG
# Art. 135 Abs. 3 StPO
# Art. 37 Abs. 1 StBOG
# Art. 39 Abs. 1 StBOG
# 1B_192/2022 E. 4.1.2
# 1B_195/2022 E. 2.2.1
# BGE 145 I 167 E. 4.1
# BGE 142 III 48 E. 4.1.1
# BGE 140 I 285 E. 6.3.1
# 2C_501/2020 E. 5.1
# BGE 145 IV 99 E. 3.1
# BGE 143 IV 40 E. 3.4.3
# BGE 139 IV 179 E. 2.2
# BGE 139 IV 186 E. 2
# BGE 143 IV 330 E. 2.1
# BGE 143 IV 316 E. 3.1
# BGE 143 IV 316 E. 3.2
# 1B_88/2022 E. 2.1
# 1B_572/2021 E. 2.1
# BGE 141 IV 360 E. 3.2
# 1B_211/2017 E. 2.1
# BGE 137 IV 122 E. 3.2
# BGE 124 I 208 E. 3
# 1B_581/2022 E. 2.1.2
# Art. 505 Abs. 1 ZGB
# Art. 520 Abs. 1 ZGB
# BGE 131 III 601 E. 3.1
# Art. 467 ZGB
# Art. 16 ZGB
# Art. 519 Abs. 1 ZGB
# BGE 124 III 5 E. 4
# BGE 131 III 106 E. 1.1
# Art. 505 Abs. 1 ZGB
# Art. 467 ZGB
# Art. 469 Abs. 1 ZGB
# Art. 471 ZGB
# Art. 20 Abs. 2 OR
# Art. 520a ZGB
# Art. 469 Abs. 2 ZGB
# Art. 458 Abs. 3 ZGB
# Art. 100 Abs. 1 BGG
# BGE 131 III 601 E. 3.1
# Art. 133 Abs. 1 ZGB
# Art. 133 Abs. 2 ZGB
# Art. 285 Abs. 1 ZGB
# Art. 100 Abs. 1 BGG
# BGE 131 III 209 E. 5
# BGE 128 III 411 E. 3.2.1
# Art. 274 Abs. 2 ZGB
# BGE 130 III 585 E. 2.1
# BGE 130 III 585 E. 2.2.1
# Art. 273 Abs. 1 ZGB
# BGE 126 III 219 E. 2
# Art. 1 Abs. 1 OR
# Art. 18 Abs. 1 OR
# Art. 363 OR
# Art. 364 Abs. 1 OR
# Art. 97 Abs. 1 OR
# Art. 248 Abs. 1 OR
# Art. 93 Abs. 1 BGG
# Art. 100 Abs. 1 BGG
# BGE 128 III 419 E. 2.2
# BGE 130 III 417 E. 3.2
# BGE 121 IV 207 E. 2a
# Art. 398 Abs. 2 OR
# Art. 41 Abs. 1 OR
# Art. 99 Abs. 2 OR
# BGE 137 III 539 E. 4.1
# BGE 137 III 539 E. 5.1
# BGE 137 III 539 E. 5.2
# BGE 129 III 181 E. 3.2
# Art. 98 Abs. 2 IPRG
# Art. 100 Abs. 1 IPRG
# Art. 641 Abs. 2 ZGB
# Art. 292 StGB
# Art. 197 Abs. 1 ZGB
# Art. 3 Abs. 2 ZGB
# Art. 933 ZGB
# Art. 940 Abs. 1 ZGB
# Art. 934 Abs. 1 ZGB
# Art. 934 Abs. 1bis ZGB
# Art. 934 Abs. 2 ZGB
# Art. 8 ZGB
# Art. 245 Abs. 2 OR
# Art. 15 OR
# Art. 16 ZGB
# BGE 139 III 305 E. 5
# BGE 132 III 155 E. 4
# BGE 144 III 264 E. 5.1
# BGE 141 III 433 E. 2.5.1
# Art. 107 Abs. 2 BGG
# Art. 333 Abs. 1 StGB
# Art. 333 Abs. 1 StPO
# Art. 314 StGB
# Art. 428 Abs. 1 StPO
# Art. 429 Abs. 1 StPO
# Art. 436 Abs. 1 StPO
# Art. 436 Abs. 2 StPO
# Art. 42 Abs. 1 StGB
# Art. 44 Abs. 1 StGB
# Art. 49 Abs. 2 StGB
# Art. 50 StGB
# Art. 100 Abs. 1 BGG
# BGE 131 III 91 E. 5.2
# 6B_1233/2016 E. 1
# BGE 135 III 334 E. 2
# 6B_904/2020 E. 1.1
# BGE 149 IV 42 E. 3.5
# Art. 110 Abs. 3 StGB
# Art. 12 Abs. 1 StGB
# Art. 25 StGB
# Art. 26 StGB
# Art. 29 Abs. 2 BV
# Art. 32 Abs. 2 BV
# Art. 9 Abs. 1 StPO
# 6B_128/2014 E. 5.2.2
# 6B_1110/2014 E. 2.3
# BGE 143 IV 63 E. 2.2
# BGE 141 IV 132 E. 3.4.1
# Art. 308 Abs. 1 ZGB
# Art. 129 Abs. 3 ZGB
# Art. 285 Abs. 1 ZGB
# Art. 277 Abs. 2 ZGB
# Art. 288 Abs. 1 ZGB
# Art. 291 ZGB
# Art. 292 ZGB
# Art. 100 Abs. 1 BGG
# Art. 277 Abs. 1 ZGB
# Art. 286 Abs. 1 ZGB
# Art. 286 Abs. 2 ZGB
# 5A_561/2020 E. 5.1.1
# 5A_954/2015 E. 3.3
# BGE 137 III 193 E. 2.1
# Art. 405 Abs. 1 ZPO
# Art. 300 ZPO
# Art. 397 Abs. 1 OR
# Art. 100 Abs. 1 OR
# Art. 100 Abs. 2 OR
# Art. 101 Abs. 3 OR
# Art. 4 ZGB
# Art. 2 Abs. 2 ZGB
# Art. 84 Abs. 1 OR
# Art. 84 Abs. 2 OR
# Art. 67 Abs. 1 SchKG
# Art. 100 Abs. 1 BGG
# Art. 176 Abs. 1 ZPO
# Art. 181 Abs. 3 ZPO
# BGE 132 III 449 E. 2
# BGE 128 III 76 E. 1b
# BGE 127 III 147 E. 2c
# BGE 134 III 151 E. 2.4
# BGE 134 III 151 E. 2.5
# BGE 146 III 326 E. 5.2
# BGE 146 III 326 E. 6.1
# 4A_379/2016 E. 3.3.1
# 4A_42/2015 E. 5.5
# 4A_42/2015 E. 6.3
# 4A_42/2015 E. 6.6
